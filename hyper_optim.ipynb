# %%
from hyperopt import hp, fmin, tpe, Trials, STATUS_OK
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

# %%
# Define the choices explicitly
hidden_size_choices = [32, 64, 128, 256]
num_layers_choices = [2, 3, 4]
# activation_choices = [nn.ReLU, nn.Tanh, nn.Sigmoid]
l2_reg_lower, l2_reg_upper = 1e-6, 1e-2

# %%
# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# Generate synthetic data (y = sin(x) + noise)
np.random.seed(42)
x = np.linspace(-2*np.pi, 2*np.pi, 100).reshape(-1, 1)
y = np.sin(x) + 0.05 * np.random.randn(100, 1)

# Convert to PyTorch tensors
x_tensor = torch.tensor(x, dtype=torch.float32).to(device)
y_tensor = torch.tensor(y, dtype=torch.float32).to(device)

# Split data into train and validation sets
x_train, x_val, y_train, y_val = train_test_split(x_tensor.cpu().numpy(), y_tensor.cpu().numpy(), test_size=0.2, random_state=42)
x_train, x_val = torch.tensor(x_train, dtype=torch.float32).to(device), torch.tensor(x_val, dtype=torch.float32).to(device)
y_train, y_val = torch.tensor(y_train, dtype=torch.float32).to(device), torch.tensor(y_val, dtype=torch.float32).to(device)

# Define the hyperparameter search space
space = {
    'num_layers': hp.choice('num_layers', num_layers_choices),  # Number of hidden layers
    'hidden_size': hp.choice('hidden_size', hidden_size_choices),  # Neurons per layer
    'l2_reg': hp.loguniform('l2_reg', np.log(l2_reg_lower), np.log(l2_reg_upper))  # L2 regularization strength
}
# Out:
# /home/yang/miniconda3/envs/pytorch-env/lib/python3.10/site-packages/torch/cuda/__init__.py:129: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
space['hidden_size'].inputs
# Out:
# <bound method Apply.inputs of <hyperopt.pyll.base.Apply object at 0x7539d30e66e0>>

# %%
# Define a neural network model
class SimpleNN(nn.Module):
    def __init__(self, num_layers, hidden_size):   # num_layers: number of hidden layers
        super(SimpleNN, self).__init__()
        layers = [nn.Linear(1, hidden_size), nn.Tanh()]
        for _ in range(num_layers - 1):
            layers.append(nn.Linear(hidden_size, hidden_size))
            layers.append(nn.Tanh())
        layers.append(nn.Linear(hidden_size, 1))
        self.network = nn.Sequential(*layers)

    def forward(self, x):
        return self.network(x)

class EarlyStopping:
    def __init__(self, patience=50, min_delta=1e-4):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = float("inf")
        self.wait = 0

    def step(self, val_loss):
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.wait = 0
        else:
            self.wait += 1

        return self.wait >= self.patience
    
# Training function with K-Fold CV
def train_model_kfold(model, x_data, y_data, k=5, epochs=500, lr=0.01):
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    fold_results = []

    for fold, (train_idx, val_idx) in enumerate(kf.split(x_data)):
        print(f"\n🔹 Fold {fold + 1}/{k} 🔹")

        train_x, train_y = x_data[train_idx], y_data[train_idx]
        val_x, val_y = x_data[val_idx], y_data[val_idx]

        # model = SimpleNN().to(device)
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=lr)

        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=50)

        train_losses, val_losses = [], []

        # Usage in training loop
        early_stopping = EarlyStopping(patience=50)

        for epoch in range(epochs):
            model.train()
            optimizer.zero_grad()
            y_pred = model(train_x)
            loss = criterion(y_pred, train_y)
            loss.backward()
            optimizer.step()
            train_losses.append(loss.item())

            # Validation loss (k-fold CV)
            model.eval()
            with torch.no_grad():
                val_pred = model(val_x)
                val_loss = criterion(val_pred, val_y).item()
                val_losses.append(val_loss)

            scheduler.step(val_loss)

            if epoch % 100 == 0:
                print(f"Epoch {epoch}, Train Loss: {loss.item():.6f}, Val Loss: {val_loss:.6f}, LR: {optimizer.param_groups[0]['lr']:.6f}")

            # Check early stopping condition
            if early_stopping.step(val_loss):
                print(f"Stopping early at epoch {epoch}")
                break

        fold_results.append((train_losses, val_losses))

    avg_val_loss = np.mean([loss[-1] for _, loss in fold_results])
    print(f"\n✅ Average Validation Loss Across {k} Folds: {avg_val_loss:.6f}")

    return avg_val_loss

# Function to evaluate a given set of hyperparameters
def objective(params):
    print(f"Testing with: {params}")

    # Create the model with the given hyperparameters
    model = SimpleNN(num_layers=params['num_layers'], hidden_size=params['hidden_size']).to(device)
    
    # Train the model with K-Fold CV
    val_loss = train_model_kfold(model, x_tensor, y_tensor, k=5, epochs=500, lr=0.01)

    print(f"Validation Loss: {val_loss:.6f}")

    return {'loss': val_loss, 'status': STATUS_OK}

# %%
# Create a trials object to store optimization history
trials = Trials()

# Run Bayesian optimization
best_hyperparams = fmin(
    fn=objective,        # Function to minimize (validation loss)
    space=space,         # Hyperparameter search space
    algo=tpe.suggest,    # Tree-structured Parzen Estimator (TPE)
    max_evals=200,        # Number of trials to run
    trials=trials        # Store results
)

print("\n🎯 Best Hyperparameters Found:")
print(best_hyperparams)
# Out:
# Testing with: {'hidden_size': 256, 'l2_reg': 3.701479138793044e-05, 'num_layers': 3}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.540316, Val Loss: 16.892603, LR: 0.010000
# Epoch 100, Train Loss: 0.035941, Val Loss: 0.044430, LR: 0.010000
# Stopping early at epoch 128
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.038420, Val Loss: 10.606874, LR: 0.010000
#   0%|          | 0/200 [00:00<?, ?trial/s, best loss=?]
# /home/yang/miniconda3/envs/pytorch-env/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 100, Train Loss: 0.024913, Val Loss: 0.030829, LR: 0.010000
# Epoch 200, Train Loss: 0.002672, Val Loss: 0.012111, LR: 0.010000
# Epoch 300, Train Loss: 0.001302, Val Loss: 0.010020, LR: 0.010000
# Epoch 400, Train Loss: 0.001050, Val Loss: 0.009505, LR: 0.010000
# Stopping early at epoch 468
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.003006, Val Loss: 4.562600, LR: 0.010000
# Epoch 100, Train Loss: 0.001824, Val Loss: 0.004903, LR: 0.010000
# Stopping early at epoch 172
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.001531, Val Loss: 2.669500, LR: 0.010000
# Epoch 100, Train Loss: 0.000762, Val Loss: 0.017401, LR: 0.010000
# Epoch 200, Train Loss: 0.001785, Val Loss: 0.016243, LR: 0.010000
# Stopping early at epoch 247
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.004198, Val Loss: 5.864140, LR: 0.010000
# Epoch 100, Train Loss: 0.000408, Val Loss: 0.012380, LR: 0.010000
# Stopping early at epoch 128
#
# ✅ Average Validation Loss Across 5 Folds: 0.016816
# Validation Loss: 0.016816
# Testing with: {'hidden_size': 256, 'l2_reg': 0.00494032017737608, 'num_layers': 4}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.485373, Val Loss: 9.740592, LR: 0.010000
# Epoch 100, Train Loss: 0.046239, Val Loss: 0.053842, LR: 0.010000
# Epoch 200, Train Loss: 0.034878, Val Loss: 0.041635, LR: 0.010000
# Stopping early at epoch 277
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.039455, Val Loss: 9.051494, LR: 0.010000
# Epoch 100, Train Loss: 0.070588, Val Loss: 0.093211, LR: 0.010000
# Epoch 200, Train Loss: 0.040851, Val Loss: 0.042528, LR: 0.010000
# Epoch 300, Train Loss: 0.043561, Val Loss: 0.049455, LR: 0.010000
# Stopping early at epoch 316
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.030883, Val Loss: 10.094472, LR: 0.010000
# Epoch 100, Train Loss: 0.031584, Val Loss: 0.015490, LR: 0.010000
# Epoch 200, Train Loss: 0.022088, Val Loss: 0.007710, LR: 0.010000
# Epoch 300, Train Loss: 0.021597, Val Loss: 0.007197, LR: 0.010000
# Stopping early at epoch 352
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.010333, Val Loss: 6.667809, LR: 0.010000
# Epoch 100, Train Loss: 0.006876, Val Loss: 0.083082, LR: 0.010000
# Stopping early at epoch 111
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.026557, Val Loss: 7.368772, LR: 0.010000
# Epoch 100, Train Loss: 0.012533, Val Loss: 0.039193, LR: 0.010000
# Stopping early at epoch 110
#
# ✅ Average Validation Loss Across 5 Folds: 0.039826
# Validation Loss: 0.039826
# Testing with: {'hidden_size': 32, 'l2_reg': 0.0006042030135630183, 'num_layers': 4}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.523794, Val Loss: 0.472334, LR: 0.010000
# Epoch 100, Train Loss: 0.033095, Val Loss: 0.038248, LR: 0.010000
# Epoch 200, Train Loss: 0.002893, Val Loss: 0.003926, LR: 0.010000
# Stopping early at epoch 262
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.002943, Val Loss: 2.043739, LR: 0.010000
# Epoch 100, Train Loss: 0.018443, Val Loss: 0.021475, LR: 0.010000
# Epoch 200, Train Loss: 0.002097, Val Loss: 0.002481, LR: 0.010000
# Epoch 300, Train Loss: 0.001967, Val Loss: 0.002311, LR: 0.010000
# Stopping early at epoch 327
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.001971, Val Loss: 1.962797, LR: 0.010000
# Epoch 100, Train Loss: 0.020376, Val Loss: 0.015229, LR: 0.010000
# Epoch 200, Train Loss: 0.002209, Val Loss: 0.003764, LR: 0.010000
# Epoch 300, Train Loss: 0.001810, Val Loss: 0.002711, LR: 0.010000
# Stopping early at epoch 367
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.002143, Val Loss: 0.288614, LR: 0.010000
# Epoch 100, Train Loss: 0.002153, Val Loss: 0.012211, LR: 0.010000
# Epoch 200, Train Loss: 0.001876, Val Loss: 0.007462, LR: 0.010000
# Epoch 300, Train Loss: 0.001774, Val Loss: 0.005098, LR: 0.010000
# Epoch 400, Train Loss: 0.001690, Val Loss: 0.003545, LR: 0.010000
# Stopping early at epoch 497
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001729, Val Loss: 0.736032, LR: 0.010000
# Epoch 100, Train Loss: 0.001159, Val Loss: 0.003455, LR: 0.010000
# Stopping early at epoch 103
#
# ✅ Average Validation Loss Across 5 Folds: 0.002864
# Validation Loss: 0.002864
# Testing with: {'hidden_size': 64, 'l2_reg': 0.006988259255380562, 'num_layers': 2}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.656334, Val Loss: 2.441212, LR: 0.010000
# Epoch 100, Train Loss: 0.047908, Val Loss: 0.059636, LR: 0.010000
# Epoch 200, Train Loss: 0.017701, Val Loss: 0.027122, LR: 0.010000
# Epoch 300, Train Loss: 0.002563, Val Loss: 0.004095, LR: 0.010000
# Epoch 400, Train Loss: 0.001819, Val Loss: 0.002272, LR: 0.010000
# Stopping early at epoch 475
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.001904, Val Loss: 0.710492, LR: 0.010000
# Epoch 100, Train Loss: 0.001829, Val Loss: 0.002011, LR: 0.010000
# Stopping early at epoch 111
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.001787, Val Loss: 0.169419, LR: 0.010000
# Epoch 100, Train Loss: 0.001308, Val Loss: 0.003915, LR: 0.010000
# Stopping early at epoch 107
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.002057, Val Loss: 0.225413, LR: 0.010000
# Stopping early at epoch 84
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001615, Val Loss: 0.355564, LR: 0.010000
# Stopping early at epoch 78
#
# ✅ Average Validation Loss Across 5 Folds: 0.002940
# Validation Loss: 0.002940
# Testing with: {'hidden_size': 128, 'l2_reg': 0.004450044793903877, 'num_layers': 3}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.476225, Val Loss: 0.673178, LR: 0.010000
# Epoch 100, Train Loss: 0.032766, Val Loss: 0.040796, LR: 0.010000
# Epoch 200, Train Loss: 0.003400, Val Loss: 0.004933, LR: 0.010000
# Epoch 300, Train Loss: 0.001683, Val Loss: 0.002420, LR: 0.010000
# Stopping early at epoch 367
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.001874, Val Loss: 3.612920, LR: 0.010000
# Epoch 100, Train Loss: 0.001538, Val Loss: 0.001937, LR: 0.010000
# Stopping early at epoch 136
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.001597, Val Loss: 0.510602, LR: 0.010000
# Stopping early at epoch 94
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.002221, Val Loss: 0.659544, LR: 0.010000
# Epoch 100, Train Loss: 0.001124, Val Loss: 0.002908, LR: 0.010000
# Stopping early at epoch 121
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.003441, Val Loss: 0.863322, LR: 0.010000
# Stopping early at epoch 96
#
# ✅ Average Validation Loss Across 5 Folds: 0.004057
# Validation Loss: 0.004057
# Testing with: {'hidden_size': 32, 'l2_reg': 1.7273975780255125e-05, 'num_layers': 4}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.522075, Val Loss: 0.510115, LR: 0.010000
# Epoch 100, Train Loss: 0.024676, Val Loss: 0.071281, LR: 0.010000
# Epoch 200, Train Loss: 0.002420, Val Loss: 0.003239, LR: 0.010000
# Stopping early at epoch 268
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.002603, Val Loss: 0.810954, LR: 0.010000
# Epoch 100, Train Loss: 0.003179, Val Loss: 0.002716, LR: 0.010000
# Epoch 200, Train Loss: 0.001908, Val Loss: 0.002108, LR: 0.010000
# Stopping early at epoch 212
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.001944, Val Loss: 1.362097, LR: 0.010000
# Epoch 100, Train Loss: 0.001867, Val Loss: 0.002495, LR: 0.010000
# Stopping early at epoch 153
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.002059, Val Loss: 0.194367, LR: 0.010000
# Stopping early at epoch 91
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.002213, Val Loss: 0.444080, LR: 0.010000
# Stopping early at epoch 98
#
# ✅ Average Validation Loss Across 5 Folds: 0.003141
# Validation Loss: 0.003141
# Testing with: {'hidden_size': 256, 'l2_reg': 3.12840903603509e-05, 'num_layers': 2}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.539198, Val Loss: 41.188351, LR: 0.010000
# Epoch 100, Train Loss: 0.021100, Val Loss: 0.033935, LR: 0.010000
# Epoch 200, Train Loss: 0.011291, Val Loss: 0.022192, LR: 0.010000
# Epoch 300, Train Loss: 0.005435, Val Loss: 0.012202, LR: 0.010000
# Epoch 400, Train Loss: 0.003019, Val Loss: 0.006788, LR: 0.010000
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.002762, Val Loss: 5.734559, LR: 0.010000
# Epoch 100, Train Loss: 0.006946, Val Loss: 0.006079, LR: 0.010000
# Epoch 200, Train Loss: 0.001212, Val Loss: 0.002262, LR: 0.010000
# Stopping early at epoch 202
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.001512, Val Loss: 0.413752, LR: 0.010000
# Epoch 100, Train Loss: 0.000721, Val Loss: 0.004233, LR: 0.010000
# Stopping early at epoch 102
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.001719, Val Loss: 2.002437, LR: 0.010000
# Stopping early at epoch 84
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.010886, Val Loss: 3.226294, LR: 0.010000
# Epoch 100, Train Loss: 0.001392, Val Loss: 0.006933, LR: 0.010000
# Stopping early at epoch 199
#
# ✅ Average Validation Loss Across 5 Folds: 0.010240
# Validation Loss: 0.010240
# Testing with: {'hidden_size': 32, 'l2_reg': 1.9227932814771156e-06, 'num_layers': 4}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.591668, Val Loss: 0.459529, LR: 0.010000
# Epoch 100, Train Loss: 0.019819, Val Loss: 0.031092, LR: 0.010000
# Epoch 200, Train Loss: 0.003643, Val Loss: 0.005556, LR: 0.010000
# Epoch 300, Train Loss: 0.004006, Val Loss: 0.005407, LR: 0.010000
# Stopping early at epoch 339
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.002270, Val Loss: 0.830193, LR: 0.010000
# Epoch 100, Train Loss: 0.002648, Val Loss: 0.002192, LR: 0.010000
# Stopping early at epoch 145
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.002079, Val Loss: 1.015540, LR: 0.010000
# Epoch 100, Train Loss: 0.001845, Val Loss: 0.003782, LR: 0.010000
# Stopping early at epoch 165
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.001931, Val Loss: 0.273797, LR: 0.010000
# Stopping early at epoch 98
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001439, Val Loss: 0.302892, LR: 0.010000
# Epoch 100, Train Loss: 0.001200, Val Loss: 0.003825, LR: 0.010000
# Stopping early at epoch 105
#
# ✅ Average Validation Loss Across 5 Folds: 0.002755
# Validation Loss: 0.002755
# Testing with: {'hidden_size': 256, 'l2_reg': 7.746093158052375e-06, 'num_layers': 4}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.534913, Val Loss: 8.144489, LR: 0.010000
# Epoch 100, Train Loss: 0.024416, Val Loss: 0.024464, LR: 0.010000
# Epoch 200, Train Loss: 0.005053, Val Loss: 0.012909, LR: 0.010000
# Epoch 300, Train Loss: 0.006434, Val Loss: 0.015482, LR: 0.010000
# Stopping early at epoch 386
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.003066, Val Loss: 4.809580, LR: 0.010000
# Epoch 100, Train Loss: 0.036937, Val Loss: 0.040138, LR: 0.010000
# Epoch 200, Train Loss: 0.027430, Val Loss: 0.032764, LR: 0.010000
# Stopping early at epoch 290
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.021859, Val Loss: 8.791986, LR: 0.010000
# Epoch 100, Train Loss: 0.021158, Val Loss: 0.009783, LR: 0.010000
# Epoch 200, Train Loss: 0.005390, Val Loss: 0.005107, LR: 0.010000
# Stopping early at epoch 248
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.002222, Val Loss: 1.640435, LR: 0.010000
# Epoch 100, Train Loss: 0.021567, Val Loss: 0.026220, LR: 0.010000
# Stopping early at epoch 107
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.020375, Val Loss: 7.926323, LR: 0.010000
# Epoch 100, Train Loss: 0.005920, Val Loss: 0.017671, LR: 0.010000
# Epoch 200, Train Loss: 0.001556, Val Loss: 0.008709, LR: 0.010000
# Epoch 300, Train Loss: 0.000475, Val Loss: 0.007219, LR: 0.010000
# Stopping early at epoch 351
#
# ✅ Average Validation Loss Across 5 Folds: 0.021152
# Validation Loss: 0.021152
# Testing with: {'hidden_size': 64, 'l2_reg': 2.9325526252772e-05, 'num_layers': 2}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.627326, Val Loss: 1.793234, LR: 0.010000
# Epoch 100, Train Loss: 0.048985, Val Loss: 0.058942, LR: 0.010000
# Epoch 200, Train Loss: 0.020875, Val Loss: 0.025325, LR: 0.010000
# Epoch 300, Train Loss: 0.003170, Val Loss: 0.004002, LR: 0.010000
# Epoch 400, Train Loss: 0.001886, Val Loss: 0.002537, LR: 0.010000
# Stopping early at epoch 467
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.002373, Val Loss: 2.347733, LR: 0.010000
# Epoch 100, Train Loss: 0.002389, Val Loss: 0.002221, LR: 0.010000
# Stopping early at epoch 168
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.001884, Val Loss: 0.488337, LR: 0.010000
# Epoch 100, Train Loss: 0.001427, Val Loss: 0.003046, LR: 0.010000
# Stopping early at epoch 113
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.001852, Val Loss: 0.292034, LR: 0.010000
# Stopping early at epoch 85
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.002078, Val Loss: 0.248400, LR: 0.010000
# Stopping early at epoch 89
#
# ✅ Average Validation Loss Across 5 Folds: 0.003361
# Validation Loss: 0.003361
# Testing with: {'hidden_size': 32, 'l2_reg': 8.282622382020907e-06, 'num_layers': 3}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.517760, Val Loss: 0.495538, LR: 0.010000
# Epoch 100, Train Loss: 0.027838, Val Loss: 0.042855, LR: 0.010000
# Epoch 200, Train Loss: 0.002917, Val Loss: 0.003905, LR: 0.010000
# Epoch 300, Train Loss: 0.001978, Val Loss: 0.001854, LR: 0.010000
# Stopping early at epoch 385
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.002073, Val Loss: 0.845866, LR: 0.010000
# Epoch 100, Train Loss: 0.002401, Val Loss: 0.002478, LR: 0.010000
# Stopping early at epoch 181
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.001867, Val Loss: 0.806738, LR: 0.010000
# Epoch 100, Train Loss: 0.001744, Val Loss: 0.002703, LR: 0.010000
# Stopping early at epoch 187
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.002128, Val Loss: 0.475283, LR: 0.010000
# Epoch 100, Train Loss: 0.002169, Val Loss: 0.005615, LR: 0.010000
# Epoch 200, Train Loss: 0.001922, Val Loss: 0.004340, LR: 0.010000
# Epoch 300, Train Loss: 0.001864, Val Loss: 0.003826, LR: 0.010000
# Epoch 400, Train Loss: 0.001834, Val Loss: 0.003344, LR: 0.010000
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001935, Val Loss: 0.491761, LR: 0.010000
# Epoch 100, Train Loss: 0.001548, Val Loss: 0.003524, LR: 0.010000
# Stopping early at epoch 121
#
# ✅ Average Validation Loss Across 5 Folds: 0.002554
# Validation Loss: 0.002554
# Testing with: {'hidden_size': 256, 'l2_reg': 0.0018314083357526165, 'num_layers': 3}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.603054, Val Loss: 6.169632, LR: 0.010000
# Epoch 100, Train Loss: 0.192031, Val Loss: 0.150525, LR: 0.010000
# Epoch 200, Train Loss: 0.033554, Val Loss: 0.041362, LR: 0.010000
# Stopping early at epoch 296
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.037048, Val Loss: 10.376520, LR: 0.010000
# Stopping early at epoch 94
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.068363, Val Loss: 0.624912, LR: 0.010000
# Stopping early at epoch 97
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.025242, Val Loss: 7.763950, LR: 0.010000
# Stopping early at epoch 86
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.024692, Val Loss: 5.268660, LR: 0.010000
# Epoch 100, Train Loss: 0.007665, Val Loss: 0.010949, LR: 0.010000
# Epoch 200, Train Loss: 0.000379, Val Loss: 0.005524, LR: 0.010000
# Stopping early at epoch 207
#
# ✅ Average Validation Loss Across 5 Folds: 0.055099
# Validation Loss: 0.055099
# Testing with: {'hidden_size': 256, 'l2_reg': 0.00029826458372098427, 'num_layers': 3}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.518333, Val Loss: 18.904100, LR: 0.010000
# Epoch 100, Train Loss: 0.152423, Val Loss: 0.157686, LR: 0.010000
# Epoch 200, Train Loss: 0.033980, Val Loss: 0.041837, LR: 0.010000
# Epoch 300, Train Loss: 0.033468, Val Loss: 0.041399, LR: 0.010000
# Epoch 400, Train Loss: 0.033222, Val Loss: 0.041031, LR: 0.010000
# Stopping early at epoch 478
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.036926, Val Loss: 10.034780, LR: 0.010000
# Epoch 100, Train Loss: 0.028922, Val Loss: 0.029274, LR: 0.010000
# Epoch 200, Train Loss: 0.014131, Val Loss: 0.026185, LR: 0.010000
# Stopping early at epoch 298
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.002118, Val Loss: 2.371624, LR: 0.010000
# Stopping early at epoch 99
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.022493, Val Loss: 2.749000, LR: 0.010000
# Epoch 100, Train Loss: 0.000399, Val Loss: 0.007086, LR: 0.010000
# Epoch 200, Train Loss: 0.000286, Val Loss: 0.004904, LR: 0.010000
# Epoch 300, Train Loss: 0.001075, Val Loss: 0.004672, LR: 0.010000
# Stopping early at epoch 355
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001302, Val Loss: 2.724730, LR: 0.010000
# Epoch 100, Train Loss: 0.000570, Val Loss: 0.005707, LR: 0.010000
# Stopping early at epoch 108
#
# ✅ Average Validation Loss Across 5 Folds: 0.014766
# Validation Loss: 0.014766
# Testing with: {'hidden_size': 256, 'l2_reg': 9.96984869243496e-05, 'num_layers': 2}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.598615, Val Loss: 45.459785, LR: 0.010000
# Epoch 100, Train Loss: 0.028206, Val Loss: 0.040149, LR: 0.010000
# Epoch 200, Train Loss: 0.009953, Val Loss: 0.014831, LR: 0.010000
# Epoch 300, Train Loss: 0.003302, Val Loss: 0.006079, LR: 0.010000
# Epoch 400, Train Loss: 0.001760, Val Loss: 0.003530, LR: 0.010000
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.001832, Val Loss: 6.158591, LR: 0.010000
# Epoch 100, Train Loss: 0.005060, Val Loss: 0.004715, LR: 0.010000
# Epoch 200, Train Loss: 0.001162, Val Loss: 0.002709, LR: 0.010000
# Stopping early at epoch 204
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.001608, Val Loss: 0.613434, LR: 0.010000
# Stopping early at epoch 96
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.001815, Val Loss: 1.974663, LR: 0.010000
# Stopping early at epoch 83
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.017342, Val Loss: 3.373757, LR: 0.010000
# Epoch 100, Train Loss: 0.001383, Val Loss: 0.007335, LR: 0.010000
# Stopping early at epoch 163
#
# ✅ Average Validation Loss Across 5 Folds: 0.014918
# Validation Loss: 0.014918
# Testing with: {'hidden_size': 64, 'l2_reg': 3.244188812040568e-06, 'num_layers': 4}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.510431, Val Loss: 0.535586, LR: 0.010000
# Epoch 100, Train Loss: 0.006250, Val Loss: 0.010233, LR: 0.010000
# Epoch 200, Train Loss: 0.001842, Val Loss: 0.002368, LR: 0.010000
# Stopping early at epoch 291
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.007469, Val Loss: 2.840158, LR: 0.010000
# Epoch 100, Train Loss: 0.004082, Val Loss: 0.003254, LR: 0.010000
# Stopping early at epoch 160
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.001957, Val Loss: 0.621756, LR: 0.010000
# Epoch 100, Train Loss: 0.001491, Val Loss: 0.002974, LR: 0.010000
# Stopping early at epoch 115
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.001965, Val Loss: 0.216664, LR: 0.010000
# Epoch 100, Train Loss: 0.001670, Val Loss: 0.004389, LR: 0.010000
# Stopping early at epoch 135
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.004226, Val Loss: 0.800552, LR: 0.010000
# Epoch 100, Train Loss: 0.003757, Val Loss: 0.008462, LR: 0.010000
# Epoch 200, Train Loss: 0.000929, Val Loss: 0.004716, LR: 0.010000
# Stopping early at epoch 209
#
# ✅ Average Validation Loss Across 5 Folds: 0.005467
# Validation Loss: 0.005467
# Testing with: {'hidden_size': 64, 'l2_reg': 3.748212696429855e-05, 'num_layers': 4}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.515052, Val Loss: 0.301776, LR: 0.010000
# Epoch 100, Train Loss: 0.025975, Val Loss: 0.028928, LR: 0.010000
# Epoch 200, Train Loss: 0.006352, Val Loss: 0.006375, LR: 0.010000
# Stopping early at epoch 240
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.002215, Val Loss: 1.546012, LR: 0.010000
# Epoch 100, Train Loss: 0.002091, Val Loss: 0.002446, LR: 0.010000
# Stopping early at epoch 191
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.002589, Val Loss: 2.239198, LR: 0.010000
# Stopping early at epoch 97
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.002019, Val Loss: 0.123301, LR: 0.010000
# Epoch 100, Train Loss: 0.001603, Val Loss: 0.002410, LR: 0.010000
# Stopping early at epoch 173
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001917, Val Loss: 0.951292, LR: 0.010000
# Epoch 100, Train Loss: 0.001034, Val Loss: 0.005903, LR: 0.010000
# Stopping early at epoch 161
#
# ✅ Average Validation Loss Across 5 Folds: 0.003349
# Validation Loss: 0.003349
# Testing with: {'hidden_size': 64, 'l2_reg': 3.166513387316058e-05, 'num_layers': 4}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.527399, Val Loss: 0.764268, LR: 0.010000
# Epoch 100, Train Loss: 0.010415, Val Loss: 0.015794, LR: 0.010000
# Epoch 200, Train Loss: 0.002101, Val Loss: 0.004153, LR: 0.010000
# Stopping early at epoch 249
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.002059, Val Loss: 1.412489, LR: 0.010000
# Epoch 100, Train Loss: 0.001707, Val Loss: 0.002517, LR: 0.010000
# Stopping early at epoch 119
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.001952, Val Loss: 0.731254, LR: 0.010000
# Epoch 100, Train Loss: 0.001448, Val Loss: 0.002780, LR: 0.010000
# Stopping early at epoch 133
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.002170, Val Loss: 1.754603, LR: 0.010000
# Epoch 100, Train Loss: 0.002173, Val Loss: 0.009780, LR: 0.010000
# Epoch 200, Train Loss: 0.001585, Val Loss: 0.002073, LR: 0.010000
# Stopping early at epoch 219
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001588, Val Loss: 1.184587, LR: 0.010000
# Stopping early at epoch 93
#
# ✅ Average Validation Loss Across 5 Folds: 0.002891
# Validation Loss: 0.002891
# Testing with: {'hidden_size': 128, 'l2_reg': 3.3357529041427197e-06, 'num_layers': 3}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.538968, Val Loss: 6.462366, LR: 0.010000
# Epoch 100, Train Loss: 0.036266, Val Loss: 0.046089, LR: 0.010000
# Epoch 200, Train Loss: 0.017930, Val Loss: 0.024301, LR: 0.010000
# Epoch 300, Train Loss: 0.003585, Val Loss: 0.006024, LR: 0.010000
# Stopping early at epoch 325
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.002063, Val Loss: 3.257568, LR: 0.010000
# Epoch 100, Train Loss: 0.004254, Val Loss: 0.003558, LR: 0.010000
# Epoch 200, Train Loss: 0.001495, Val Loss: 0.002390, LR: 0.010000
# Stopping early at epoch 260
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.001458, Val Loss: 1.359657, LR: 0.010000
# Stopping early at epoch 90
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.001958, Val Loss: 0.677827, LR: 0.010000
# Epoch 100, Train Loss: 0.001009, Val Loss: 0.006219, LR: 0.010000
# Epoch 200, Train Loss: 0.000822, Val Loss: 0.006117, LR: 0.010000
# Stopping early at epoch 251
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001795, Val Loss: 1.084903, LR: 0.010000
# Epoch 100, Train Loss: 0.000725, Val Loss: 0.004507, LR: 0.010000
# Stopping early at epoch 136
#
# ✅ Average Validation Loss Across 5 Folds: 0.003876
# Validation Loss: 0.003876
# Testing with: {'hidden_size': 32, 'l2_reg': 5.456734189856573e-06, 'num_layers': 3}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.523939, Val Loss: 0.447184, LR: 0.010000
# Epoch 100, Train Loss: 0.046045, Val Loss: 0.115278, LR: 0.010000
# Epoch 200, Train Loss: 0.004211, Val Loss: 0.006035, LR: 0.010000
# Epoch 300, Train Loss: 0.011509, Val Loss: 0.003783, LR: 0.010000
# Stopping early at epoch 327
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.002446, Val Loss: 1.010330, LR: 0.010000
# Epoch 100, Train Loss: 0.002363, Val Loss: 0.002221, LR: 0.010000
# Stopping early at epoch 179
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.002051, Val Loss: 0.694320, LR: 0.010000
# Epoch 100, Train Loss: 0.002637, Val Loss: 0.005951, LR: 0.010000
# Epoch 200, Train Loss: 0.001581, Val Loss: 0.002975, LR: 0.010000
# Stopping early at epoch 283
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.002008, Val Loss: 0.523935, LR: 0.010000
# Epoch 100, Train Loss: 0.002054, Val Loss: 0.001632, LR: 0.010000
# Stopping early at epoch 127
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001615, Val Loss: 0.456278, LR: 0.010000
# Epoch 100, Train Loss: 0.001628, Val Loss: 0.003747, LR: 0.010000
# Stopping early at epoch 128
#
# ✅ Average Validation Loss Across 5 Folds: 0.002596
# Validation Loss: 0.002596
# Testing with: {'hidden_size': 64, 'l2_reg': 0.0005931155164541519, 'num_layers': 3}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.551188, Val Loss: 1.243163, LR: 0.010000
# Epoch 100, Train Loss: 0.023256, Val Loss: 0.029577, LR: 0.010000
# Epoch 200, Train Loss: 0.001956, Val Loss: 0.002563, LR: 0.010000
# Stopping early at epoch 267
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.002083, Val Loss: 1.009651, LR: 0.010000
# Epoch 100, Train Loss: 0.001957, Val Loss: 0.002271, LR: 0.010000
# Stopping early at epoch 121
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.002020, Val Loss: 0.917777, LR: 0.010000
# Epoch 100, Train Loss: 0.001614, Val Loss: 0.002480, LR: 0.010000
# Stopping early at epoch 121
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.002065, Val Loss: 0.774145, LR: 0.010000
# Epoch 100, Train Loss: 0.002017, Val Loss: 0.013613, LR: 0.010000
# Epoch 200, Train Loss: 0.001596, Val Loss: 0.004619, LR: 0.010000
# Epoch 300, Train Loss: 0.001468, Val Loss: 0.003131, LR: 0.010000
# Epoch 400, Train Loss: 0.001389, Val Loss: 0.002883, LR: 0.010000
# Stopping early at epoch 431
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001574, Val Loss: 0.751285, LR: 0.010000
# Epoch 100, Train Loss: 0.001191, Val Loss: 0.004914, LR: 0.010000
# Stopping early at epoch 191
#
# ✅ Average Validation Loss Across 5 Folds: 0.002944
# Validation Loss: 0.002944
# Testing with: {'hidden_size': 32, 'l2_reg': 1.1991639052113395e-06, 'num_layers': 3}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.519422, Val Loss: 0.490809, LR: 0.010000
# Epoch 100, Train Loss: 0.044780, Val Loss: 0.029196, LR: 0.010000
# Epoch 200, Train Loss: 0.005578, Val Loss: 0.006962, LR: 0.010000
# Epoch 300, Train Loss: 0.003231, Val Loss: 0.003717, LR: 0.010000
# Stopping early at epoch 302
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.004052, Val Loss: 1.167397, LR: 0.010000
# Epoch 100, Train Loss: 0.004448, Val Loss: 0.003692, LR: 0.010000
# Epoch 200, Train Loss: 0.002202, Val Loss: 0.001610, LR: 0.010000
# Stopping early at epoch 249
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.002110, Val Loss: 1.143123, LR: 0.010000
# Epoch 100, Train Loss: 0.002630, Val Loss: 0.005806, LR: 0.010000
# Epoch 200, Train Loss: 0.001678, Val Loss: 0.003325, LR: 0.010000
# Epoch 300, Train Loss: 0.001472, Val Loss: 0.002920, LR: 0.010000
# Stopping early at epoch 326
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.001959, Val Loss: 0.543713, LR: 0.010000
# Epoch 100, Train Loss: 0.002113, Val Loss: 0.002358, LR: 0.010000
# Stopping early at epoch 110
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001761, Val Loss: 0.588977, LR: 0.010000
# Epoch 100, Train Loss: 0.001493, Val Loss: 0.004174, LR: 0.010000
# Stopping early at epoch 166
#
# ✅ Average Validation Loss Across 5 Folds: 0.002997
# Validation Loss: 0.002997
# Testing with: {'hidden_size': 32, 'l2_reg': 6.381777285614691e-06, 'num_layers': 3}
# ...
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.029230, Val Loss: 5.444489, LR: 0.010000
# Epoch 100, Train Loss: 0.001793, Val Loss: 0.045116, LR: 0.010000
# Epoch 200, Train Loss: 0.000463, Val Loss: 0.023301, LR: 0.010000
# Epoch 300, Train Loss: 0.000318, Val Loss: 0.018803, LR: 0.010000
# Epoch 400, Train Loss: 0.000268, Val Loss: 0.016156, LR: 0.010000
# Stopping early at epoch 405
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.004217, Val Loss: 5.788325, LR: 0.010000
# Epoch 100, Train Loss: 0.000455, Val Loss: 0.006258, LR: 0.010000
# Stopping early at epoch 108
#
# ✅ Average Validation Loss Across 5 Folds: 0.008657
# Validation Loss: 0.008657
# Testing with: {'hidden_size': 32, 'l2_reg': 2.5166762948134854e-05, 'num_layers': 3}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.497909, Val Loss: 0.440916, LR: 0.010000
# Epoch 100, Train Loss: 0.019269, Val Loss: 0.020789, LR: 0.010000
# Epoch 200, Train Loss: 0.002996, Val Loss: 0.003938, LR: 0.010000
# Epoch 300, Train Loss: 0.032520, Val Loss: 0.012255, LR: 0.010000
# Stopping early at epoch 359
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.002391, Val Loss: 0.784167, LR: 0.010000
# Epoch 100, Train Loss: 0.002524, Val Loss: 0.001941, LR: 0.010000
# Stopping early at epoch 136
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.002071, Val Loss: 0.771900, LR: 0.010000
# Epoch 100, Train Loss: 0.001975, Val Loss: 0.003779, LR: 0.010000
# Stopping early at epoch 126
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.002522, Val Loss: 0.218876, LR: 0.010000
# Epoch 100, Train Loss: 0.002088, Val Loss: 0.002703, LR: 0.010000
# Stopping early at epoch 122
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001934, Val Loss: 0.366147, LR: 0.010000
# Epoch 100, Train Loss: 0.001769, Val Loss: 0.003866, LR: 0.010000
# Stopping early at epoch 123
#
# ✅ Average Validation Loss Across 5 Folds: 0.002843
# Validation Loss: 0.002843
# Testing with: {'hidden_size': 32, 'l2_reg': 2.0245898539730914e-06, 'num_layers': 2}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.609054, Val Loss: 0.512235, LR: 0.010000
# Epoch 100, Train Loss: 0.056421, Val Loss: 0.069615, LR: 0.010000
# Epoch 200, Train Loss: 0.009533, Val Loss: 0.013159, LR: 0.010000
# Epoch 300, Train Loss: 0.002915, Val Loss: 0.003041, LR: 0.010000
# Epoch 400, Train Loss: 0.002261, Val Loss: 0.001788, LR: 0.010000
# Stopping early at epoch 465
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.003725, Val Loss: 1.394143, LR: 0.010000
# Epoch 100, Train Loss: 0.002698, Val Loss: 0.002988, LR: 0.010000
# Epoch 200, Train Loss: 0.002120, Val Loss: 0.002205, LR: 0.010000
# Stopping early at epoch 277
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.002035, Val Loss: 0.165818, LR: 0.010000
# Stopping early at epoch 85
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.002321, Val Loss: 0.143159, LR: 0.010000
# Epoch 100, Train Loss: 0.002014, Val Loss: 0.002530, LR: 0.010000
# Stopping early at epoch 112
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001846, Val Loss: 0.313924, LR: 0.010000
# Stopping early at epoch 80
#
# ✅ Average Validation Loss Across 5 Folds: 0.003053
# Validation Loss: 0.003053
# Testing with: {'hidden_size': 32, 'l2_reg': 2.6278606350604056e-06, 'num_layers': 3}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.518908, Val Loss: 0.514118, LR: 0.010000
# Epoch 100, Train Loss: 0.029362, Val Loss: 0.038825, LR: 0.010000
# Epoch 200, Train Loss: 0.021169, Val Loss: 0.006608, LR: 0.010000
# Epoch 300, Train Loss: 0.002050, Val Loss: 0.002773, LR: 0.010000
# Epoch 400, Train Loss: 0.001889, Val Loss: 0.002031, LR: 0.010000
# Stopping early at epoch 429
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.001972, Val Loss: 0.433110, LR: 0.010000
# Epoch 100, Train Loss: 0.002024, Val Loss: 0.001986, LR: 0.010000
# Stopping early at epoch 190
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.001789, Val Loss: 0.711821, LR: 0.010000
# Epoch 100, Train Loss: 0.001874, Val Loss: 0.003541, LR: 0.010000
# Epoch 200, Train Loss: 0.001446, Val Loss: 0.003293, LR: 0.010000
# Stopping early at epoch 236
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.001936, Val Loss: 0.413989, LR: 0.010000
# Epoch 100, Train Loss: 0.001837, Val Loss: 0.003190, LR: 0.010000
# Epoch 200, Train Loss: 0.001624, Val Loss: 0.002537, LR: 0.010000
# Stopping early at epoch 225
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001624, Val Loss: 0.453466, LR: 0.010000
# Epoch 100, Train Loss: 0.001318, Val Loss: 0.003415, LR: 0.010000
# Stopping early at epoch 122
#
# ✅ Average Validation Loss Across 5 Folds: 0.002559
# Validation Loss: 0.002559
# Testing with: {'hidden_size': 128, 'l2_reg': 6.649702499494383e-06, 'num_layers': 3}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.498840, Val Loss: 0.290114, LR: 0.010000
# Epoch 100, Train Loss: 0.033354, Val Loss: 0.043355, LR: 0.010000
# Epoch 200, Train Loss: 0.011432, Val Loss: 0.031420, LR: 0.010000
# Epoch 300, Train Loss: 0.002063, Val Loss: 0.003854, LR: 0.010000
# Epoch 400, Train Loss: 0.001527, Val Loss: 0.002199, LR: 0.010000
# Stopping early at epoch 408
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.001784, Val Loss: 3.913226, LR: 0.010000
# Epoch 100, Train Loss: 0.004892, Val Loss: 0.004008, LR: 0.010000
# Stopping early at epoch 186
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.001632, Val Loss: 1.064478, LR: 0.010000
# Stopping early at epoch 99
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.002042, Val Loss: 0.523373, LR: 0.010000
# Epoch 100, Train Loss: 0.000929, Val Loss: 0.003404, LR: 0.010000
# Stopping early at epoch 107
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001478, Val Loss: 1.128225, LR: 0.010000
# Epoch 100, Train Loss: 0.001078, Val Loss: 0.005847, LR: 0.010000
# Stopping early at epoch 171
#
# ✅ Average Validation Loss Across 5 Folds: 0.003670
# Validation Loss: 0.003670
# Testing with: {'hidden_size': 32, 'l2_reg': 1.4105112492561274e-05, 'num_layers': 3}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.514267, Val Loss: 0.464930, LR: 0.010000
# Epoch 100, Train Loss: 0.022848, Val Loss: 0.044095, LR: 0.010000
# Epoch 200, Train Loss: 0.004004, Val Loss: 0.004401, LR: 0.010000
# Stopping early at epoch 274
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.003216, Val Loss: 0.819089, LR: 0.010000
# Epoch 100, Train Loss: 0.003313, Val Loss: 0.002818, LR: 0.010000
# Epoch 200, Train Loss: 0.002173, Val Loss: 0.002306, LR: 0.010000
# Stopping early at epoch 224
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.002265, Val Loss: 0.854450, LR: 0.010000
# Epoch 100, Train Loss: 0.014134, Val Loss: 0.013023, LR: 0.010000
# Epoch 200, Train Loss: 0.001689, Val Loss: 0.004013, LR: 0.010000
# Epoch 300, Train Loss: 0.001539, Val Loss: 0.002808, LR: 0.010000
# Stopping early at epoch 328
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.001861, Val Loss: 0.132574, LR: 0.010000
# Epoch 100, Train Loss: 0.002130, Val Loss: 0.002564, LR: 0.010000
# Stopping early at epoch 196
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001491, Val Loss: 0.255777, LR: 0.010000
# Epoch 100, Train Loss: 0.001337, Val Loss: 0.003144, LR: 0.010000
# Stopping early at epoch 105
#
# ✅ Average Validation Loss Across 5 Folds: 0.002808
# Validation Loss: 0.002808
# Testing with: {'hidden_size': 32, 'l2_reg': 2.2054828816470685e-05, 'num_layers': 3}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.492118, Val Loss: 0.405348, LR: 0.010000
# Epoch 100, Train Loss: 0.022951, Val Loss: 0.047171, LR: 0.010000
# Epoch 200, Train Loss: 0.003280, Val Loss: 0.005064, LR: 0.010000
# Epoch 300, Train Loss: 0.002205, Val Loss: 0.002211, LR: 0.010000
# Stopping early at epoch 356
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.002976, Val Loss: 0.568186, LR: 0.010000
# Epoch 100, Train Loss: 0.002514, Val Loss: 0.002603, LR: 0.010000
# Epoch 200, Train Loss: 0.001849, Val Loss: 0.001987, LR: 0.010000
# Stopping early at epoch 202
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.001898, Val Loss: 0.611492, LR: 0.010000
# Epoch 100, Train Loss: 0.001875, Val Loss: 0.002443, LR: 0.010000
# Stopping early at epoch 138
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.014038, Val Loss: 1.250108, LR: 0.010000
# Epoch 100, Train Loss: 0.004001, Val Loss: 0.017062, LR: 0.010000
# Epoch 200, Train Loss: 0.002115, Val Loss: 0.002135, LR: 0.010000
# Epoch 300, Train Loss: 0.001972, Val Loss: 0.001769, LR: 0.010000
# Epoch 400, Train Loss: 0.001921, Val Loss: 0.001570, LR: 0.010000
# Stopping early at epoch 417
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001569, Val Loss: 0.710089, LR: 0.010000
# Epoch 100, Train Loss: 0.002006, Val Loss: 0.003635, LR: 0.010000
# Stopping early at epoch 188
#
# ✅ Average Validation Loss Across 5 Folds: 0.004454
# Validation Loss: 0.004454
# 100%|██████████| 200/200 [04:21<00:00,  1.31s/trial, best loss: 0.0024398088455200194]
#
# 🎯 Best Hyperparameters Found:
# {'hidden_size': np.int64(0), 'l2_reg': np.float64(1.0513989419703529e-05), 'num_layers': np.int64(1)}

# %%
# Evaluate the model with the best hyperparameters
best_params = {'hidden_size': hidden_size_choices[best_hyperparams['hidden_size']], 'l2_reg': best_hyperparams['l2_reg'], 'num_layers': num_layers_choices[best_hyperparams['num_layers']]}
final_val_loss = objective(best_params)['loss']

print(f"\n🎯 Final Validation Loss with Best Hyperparameters: {final_val_loss:.6f}")
# Out:
# Testing with: {'hidden_size': 32, 'l2_reg': np.float64(1.0513989419703529e-05), 'num_layers': 3}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.556042, Val Loss: 0.498334, LR: 0.010000
# Epoch 100, Train Loss: 0.039903, Val Loss: 0.056555, LR: 0.010000
# Epoch 200, Train Loss: 0.009580, Val Loss: 0.022934, LR: 0.010000
# Stopping early at epoch 284
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.005893, Val Loss: 1.334529, LR: 0.010000
# Epoch 100, Train Loss: 0.015764, Val Loss: 0.014056, LR: 0.010000
# Stopping early at epoch 197
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.001967, Val Loss: 0.674943, LR: 0.010000
# Epoch 100, Train Loss: 0.002132, Val Loss: 0.003549, LR: 0.010000
# Epoch 200, Train Loss: 0.001770, Val Loss: 0.002419, LR: 0.010000
# Stopping early at epoch 248
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.002081, Val Loss: 0.161306, LR: 0.010000
# Epoch 100, Train Loss: 0.001919, Val Loss: 0.002537, LR: 0.010000
# Stopping early at epoch 136
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001976, Val Loss: 0.367855, LR: 0.010000
# Epoch 100, Train Loss: 0.001566, Val Loss: 0.003692, LR: 0.010000
# Stopping early at epoch 137
#
# ✅ Average Validation Loss Across 5 Folds: 0.004058
# Validation Loss: 0.004058
#
# 🎯 Final Validation Loss with Best Hyperparameters: 0.004058

# %%
# Evaluate the model with the best hyperparameters
best_params = {'hidden_size': 64, 'l2_reg': 1.0238234674533273e-06, 'num_layers': 2}
final_val_loss = objective(best_params)['loss']

print(f"\n🎯 Validation Loss with some set of Hyperparameters: {final_val_loss:.6f}")
# Out:
# Testing with: {'hidden_size': 64, 'l2_reg': 1.0238234674533273e-06, 'num_layers': 2}
#
# 🔹 Fold 1/5 🔹
# Epoch 0, Train Loss: 0.550797, Val Loss: 2.734138, LR: 0.010000
# Epoch 100, Train Loss: 0.045306, Val Loss: 0.054257, LR: 0.010000
# Epoch 200, Train Loss: 0.011895, Val Loss: 0.015785, LR: 0.010000
# Epoch 300, Train Loss: 0.002097, Val Loss: 0.003036, LR: 0.010000
# Epoch 400, Train Loss: 0.001764, Val Loss: 0.002181, LR: 0.010000
# Stopping early at epoch 453
#
# 🔹 Fold 2/5 🔹
# Epoch 0, Train Loss: 0.001902, Val Loss: 0.566046, LR: 0.010000
# Stopping early at epoch 97
#
# 🔹 Fold 3/5 🔹
# Epoch 0, Train Loss: 0.002110, Val Loss: 0.209286, LR: 0.010000
# Stopping early at epoch 86
#
# 🔹 Fold 4/5 🔹
# Epoch 0, Train Loss: 0.002138, Val Loss: 0.308353, LR: 0.010000
# Epoch 100, Train Loss: 0.001643, Val Loss: 0.003132, LR: 0.010000
# Stopping early at epoch 108
#
# 🔹 Fold 5/5 🔹
# Epoch 0, Train Loss: 0.001838, Val Loss: 0.223217, LR: 0.010000
# Stopping early at epoch 97
#
# ✅ Average Validation Loss Across 5 Folds: 0.003119
# Validation Loss: 0.003119
#
# 🎯 Final Validation Loss with Best Hyperparameters: 0.003119
